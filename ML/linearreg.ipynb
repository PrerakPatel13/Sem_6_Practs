# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
X = np.array([2,3,4,5,6,7,8,9,10]).reshape(-1,1)
Y = np.array([1,3,6,9,11,13,15,17,20])

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(X,Y)
# Out:
# LinearRegression()

# %%
print(linreg.coef_)
print(linreg.intercept_)
# Out:
# [2.33333333]
# -3.4444444444444446

# %%
Y_pred = linreg.predict(X)
plt.scatter(X,Y)
plt.xlabel("Predicated")
plt.ylabel("Actual")
plt.plot(X,Y_pred,color="black")
plt.show()

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

n = len(X)

numer = 0
denom = 0
for i in range(n):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
    m = numer / denom
    c = mean_y - (m * mean_x)

print("Linear Regression Coeffiecient b1 :",m,"Intercept of line:",c)
max_x = np.max(X)
min_x = np.min(X)
max_y = c + m * max_x 
min_y = c + m * min_x 
plt.plot([min_x,max_x],[min_y,max_y], color='blue', label='Regression Line')
plt.scatter(X, Y, c='green', label='Scatter Plot')
plt.legend()
plt.show()
# Out:
# Linear Regression Coeffiecient b1 : [2.33333333] Intercept of line: [-3.44444444]

# %%
d1 =pd.read_csv("https://raw.githubusercontent.com/PrerakPatel13/Sem_5_Practs/main/dataset/House_Rent_Dataset.csv")
reg1=linear_model.LinearRegression()
X1=d1['Size'].values.reshape(-1, 1)
Y1=d1['Rent']
reg1.fit(X1,Y1)
Y_pred = reg1.predict(X1)
plt.scatter(X1,Y1)
plt.xlabel("Size")
plt.ylabel("Rent")
plt.plot(X1,Y_pred,linewidth=1,color="red", label="Linear Regression")
plt.legend()
plt.show()

# %%
reg1.predict([[1500]])
# Out:
# array([62115.02320707])

# %%
import numpy as np

X1 = np.array([2, 3, 4, 5, 6, 7, 8, 9, 10])
Y1 = np.array([1, 3, 6, 9, 10, 13, 14, 17, 21])
b0 = 0
b1 = 0

learning_rate = 0.01
num_epochs = 1

for epoch in range(num_epochs):
    for i in range(len(X1)):
        y_pred = b0 + b1 * X1[i]
        error = Y1[i] - y_pred

        b0 += learning_rate * error
        b1 += learning_rate * error * X1[i]

x_test = 4
y_pred_test = b0 + b1 * x_test
rmse = np.sqrt(np.mean((y_pred_test - Y1[2])**2))

print("RMSE for X=4 after one epoch :", rmse)
# Out:
# RMSE for X=4 after one epoch : 2.620966203433566
